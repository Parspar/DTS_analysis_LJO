# %%
from utils import read_AsciiGrid
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.colors import LogNorm

# %%
flowacc_file = r'/Users/jpnousu/SpaFHy_RUNS/pallas/gis/flowacc.dat'
flowacc = read_AsciiGrid(flowacc_file)[0]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
im = ax.imshow(flowacc[25:200,50:150], cmap='viridis', norm=colors.LogNorm())
fig.colorbar(im, ax=ax)
